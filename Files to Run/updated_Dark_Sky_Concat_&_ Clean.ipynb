# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, Float

# %%
dark_sky_csv1 = "output_data/Dark Sky Seattle May 4th 2017 - May 4th 2018.csv"
dark_sky_csv2 = "output_data/Dark Sky Seattle May 5th 2018 - May 4th 2019.csv"

# %%
dark_sky_1 = pd.read_csv(dark_sky_csv1)
dark_sky_2 = pd.read_csv(dark_sky_csv2)

# %%
frames = [dark_sky_1, dark_sky_2]
dark_sky_df = pd.concat(frames, ignore_index=True)
dark_sky_df.reset_index
dark_sky_df.head(2)
# Out:
#           Day             Detail  Moonphase                       Summary  \
# 0  1493985600               rain       0.34          Rain in the morning.
# 1  1494072000  partly-cloudy-day       0.37  Mostly cloudy until evening.
#
#       Sunrise      Sunset  cloudCover  dewPoint  humidity  precipIntensity  \
# 0  1493988372  1494041298        0.84     49.36      0.81           0.0085
# 1  1494074682  1494127781        0.66     40.25      0.71           0.0018
#
#    ...  precipProbability  pressure  temperatureMax  temperatureMaxTime  \
# 0  ...               0.79   1012.00           59.90          1493967600
# 1  ...               0.44   1020.59           57.47          1494111600
#
#    temperatureMin  temperatureMinTime  visibility  windGust  windGustTime  \
# 0           48.07          1494050400        9.95     12.78    1494018000
# 1           43.08          1494075600       10.00      8.62    1494122400
#
#    windSpeed
# 0       2.63
# 1       0.75
#
# [2 rows x 21 columns]

# %%
len(dark_sky_df)
# Out:
# 730

# %%
dark_sky_df.drop_duplicates(subset=['Day'], keep= 'first', inplace = True)
len(dark_sky_df)
# Out:
# 730

# %%
dark_sky_df['Stan_Date'] = pd.to_datetime(dark_sky_df['Day'],unit='s')
dark_sky_df.head(1)
# Out:
#           Day Detail  Moonphase               Summary     Sunrise      Sunset  \
# 0  1493985600   rain       0.34  Rain in the morning.  1493988372  1494041298
#
#    cloudCover  dewPoint  humidity  precipIntensity  ...  pressure  \
# 0        0.84     49.36      0.81           0.0085  ...    1012.0
#
#    temperatureMax  temperatureMaxTime  temperatureMin  temperatureMinTime  \
# 0            59.9          1493967600           48.07          1494050400
#
#    visibility  windGust  windGustTime  windSpeed           Stan_Date
# 0        9.95     12.78    1494018000       2.63 2017-05-05 12:00:00
#
# [1 rows x 22 columns]

# %%
dark_sky_df['Stan_Date'] = dark_sky_df['Stan_Date'].dt.date
dark_sky_df.head(1)
# Out:
#           Day Detail  Moonphase               Summary     Sunrise      Sunset  \
# 0  1493985600   rain       0.34  Rain in the morning.  1493988372  1494041298
#
#    cloudCover  dewPoint  humidity  precipIntensity  ...  pressure  \
# 0        0.84     49.36      0.81           0.0085  ...    1012.0
#
#    temperatureMax  temperatureMaxTime  temperatureMin  temperatureMinTime  \
# 0            59.9          1493967600           48.07          1494050400
#
#    visibility  windGust  windGustTime  windSpeed   Stan_Date
# 0        9.95     12.78    1494018000       2.63  2017-05-05
#
# [1 rows x 22 columns]

# %%
dark_sky_df['Stan_Date'] = pd.to_datetime(dark_sky_df['Stan_Date'])

# %%
dark_sky_df['WEEK'] = dark_sky_df['Stan_Date'].dt.week
dark_sky_df.head(2)
# Out:
#           Day             Detail  Moonphase                       Summary  \
# 0  1493985600               rain       0.34          Rain in the morning.
# 1  1494072000  partly-cloudy-day       0.37  Mostly cloudy until evening.
#
#       Sunrise      Sunset  cloudCover  dewPoint  humidity  precipIntensity  \
# 0  1493988372  1494041298        0.84     49.36      0.81           0.0085
# 1  1494074682  1494127781        0.66     40.25      0.71           0.0018
#
#    ...  temperatureMax  temperatureMaxTime  temperatureMin  \
# 0  ...           59.90          1493967600           48.07
# 1  ...           57.47          1494111600           43.08
#
#    temperatureMinTime  visibility  windGust  windGustTime  windSpeed  \
# 0          1494050400        9.95     12.78    1494018000       2.63
# 1          1494075600       10.00      8.62    1494122400       0.75
#
#    Stan_Date  WEEK
# 0 2017-05-05    18
# 1 2017-05-06    18
#
# [2 rows x 23 columns]

# %%
dark_sky_df = dark_sky_df.reset_index()

# %%
dark_sky_week_df = dark_sky_df.groupby(['WEEK']).mean()

# %%
dark_sky_week_df.head(2)
# Out:
#       index           Day  Moonphase       Sunrise        Sunset  cloudCover  \
# WEEK
# 1     426.0  1.530792e+09   0.694286  1.530806e+09  1.530837e+09    0.657857
# 2     433.0  1.531397e+09   0.494286  1.531411e+09  1.531442e+09    0.651429
#
#        dewPoint  humidity  precipIntensity  precipIntensityMax  \
# WEEK
# 1     37.747857  0.853571         0.004650            0.019150
# 2     41.089286  0.850714         0.004793            0.019586
#
#       precipProbability     pressure  temperatureMax  temperatureMaxTime  \
# WEEK
# 1              0.532857  1018.093571       46.435714        1.530825e+09
# 2              0.600000  1015.947857       50.097857        1.531437e+09
#
#       temperatureMin  temperatureMinTime  visibility  windGust  windGustTime  \
# WEEK
# 1          37.935000        1.530811e+09    6.375714  7.647857  1.530819e+09
# 2          41.689286        1.531423e+09    6.140714  5.750714  1.531428e+09
#
#       windSpeed
# WEEK
# 1      2.168571
# ...

# %%
dark_sky_week_df = dark_sky_week_df.drop(columns = ['index','Day'])
dark_sky_week_df.head(2)
# Out:
#       Moonphase       Sunrise        Sunset  cloudCover   dewPoint  humidity  \
# WEEK
# 1      0.694286  1.530806e+09  1.530837e+09    0.657857  37.747857  0.853571
# 2      0.494286  1.531411e+09  1.531442e+09    0.651429  41.089286  0.850714
#
#       precipIntensity  precipIntensityMax  precipProbability     pressure  \
# WEEK
# 1            0.004650            0.019150           0.532857  1018.093571
# 2            0.004793            0.019586           0.600000  1015.947857
#
#       temperatureMax  temperatureMaxTime  temperatureMin  temperatureMinTime  \
# WEEK
# 1          46.435714        1.530825e+09       37.935000        1.530811e+09
# 2          50.097857        1.531437e+09       41.689286        1.531423e+09
#
#       visibility  windGust  windGustTime  windSpeed
# WEEK
# 1       6.375714  7.647857  1.530819e+09   2.168571
# 2       6.140714  5.750714  1.531428e+09   1.529286

# %%
#create data base in mysql workbench first then add name to path after local host with root password
engine = create_engine("mysql://root:RootBeer748*@localhost/bob_from_accounting")
con = engine.connect()

# %%
#loading csv file as db or createing data base from any were. 
# file = "DataOne.csv"
# file_df = pd.read_csv(file)

# %%
#Load data frame in to mysql data base as new table name then run. 
dark_sky_week_df.to_sql(name='seattle_darksky',con=con,if_exists='append')
con.close()
