# %%
import pandas as pd
import numpy as np

# %%
file = 'austin_output1.csv'
df = pd.read_csv(file)
df.head()
# Out:
#           Day               Detail  Moonphase                        Summary  \
# 0  1525521600  partly-cloudy-night       0.68  Partly cloudy in the morning.
# 1  1525608000            clear-day       0.71      Clear throughout the day.
# 2  1525694400            clear-day       0.74      Clear throughout the day.
# 3  1525780800            clear-day       0.77      Clear throughout the day.
# 4  1525867200    partly-cloudy-day       0.80  Mostly cloudy in the morning.
#
#       Sunrise      Sunset  cloudCover  dewPoint  humidity  precipIntensity  \
# 0  1525520719  1525569150        0.32     59.50      0.70              0.0
# 1  1525607072  1525655591        0.00     56.44      0.62              0.0
# 2  1525693425  1525742031        0.01     57.96      0.59              0.0
# 3  1525779780  1525828472        0.01     57.03      0.52              0.0
# 4  1525866136  1525914912        0.21     60.07      0.61              0.0
#
# ...

# %%
df.columns
#detail, tempmax/min, humidity, wind speed,precipProbability, precipMax, visibility, sunrise, sunset
# Out:
# Index(['Day', 'Detail', 'Moonphase', 'Summary', 'Sunrise', 'Sunset',
#        'cloudCover', 'dewPoint', 'humidity', 'precipIntensity',
#        'precipIntensityMax', 'precipProbability', 'pressure', 'temperatureMax',
#        'temperatureMaxTime', 'temperatureMin', 'temperatureMinTime',
#        'visibility', 'windGust', 'windGustTime', 'windSpeed'],
#       dtype='object')

# %%
df1 = df.drop( columns = [ 'Moonphase', 'cloudCover', 'dewPoint', 'precipIntensityMax', 'pressure', 'temperatureMaxTime', 'temperatureMinTime', 'windGust', 'windGustTime'])
#df['Detail', 'temperatureMax', 'temperatureMin', 'windSpeed', 'precipProbability', 'precipIntensity', 'visibility', 'Sunrise', 'Sunset']

# %%
df1['Day'] = pd.to_datetime(df1['Day'],unit='s')
df1['Sunrise'] = pd.to_datetime(df1['Sunrise'],unit='s')
df1['Sunset'] = pd.to_datetime(df1['Sunset'],unit='s')

# %%
df1['YEAR'] = df1['Day'].dt.year
df1['MONTH'] = df1['Day'].dt.month

# %%
df1 = df1.groupby('MONTH').mean()
# Out:
#        humidity  precipIntensity  precipProbability  temperatureMax  \
# MONTH
# 1      0.710000         0.001387           0.095161       60.360000
# 2      0.751429         0.000096           0.054286       63.512143
# 3      0.647097         0.000129           0.016774       68.697097
# 4      0.693333         0.004333           0.233333       78.780667
# 5      0.683226         0.001729           0.102903       89.307419
# 6      0.665667         0.000227           0.028000       94.396667
# 7      0.604194         0.000306           0.031935       97.407419
# 8      0.596129         0.000106           0.015806       97.399032
# 9      0.810000         0.001743           0.122000       85.802333
# 10     0.823871         0.001561           0.118710       76.833548
# 11     0.705333         0.000317           0.064000       65.743333
# 12     0.684839         0.002706           0.118387       61.583548
#
#        temperatureMin  visibility  windSpeed         YEAR
# MONTH
# ...

# %%
df1.to_csv('austin_weather.csv')
